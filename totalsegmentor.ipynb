# %%
import nibabel as nib
import numpy as np
import numpy.typing
import matplotlib.pyplot as plt
import os
import pydicom
import cv2
import glob


from totalsegmentator.python_api import totalsegmentator
# %matplotlib inline

# %% [markdown]
# ## Generating Water Segmentations

# %%
water_directory = "D:/GEA21/water/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/water_segmentations/GEA_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_PDFF/water/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/water_segmentations/SBIR_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_T1/water/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/water_segmentations/T1_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/WLS02_UCSD/water/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/water_segmentations/WLS_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

# %% [markdown]
# ## Generating Outphase Segmentations

# %%
water_directory = "D:/GEA21/in_out/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[1] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/out_segmentations/GEA_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_PDFF/in_out/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[1] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/out_segmentations/SBIR_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_T1/in_out/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[1] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/out_segmentations/T1_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/WLS02_UCSD/in_out/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[1] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/out_segmentations/WLS_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

# %% [markdown]
# ## Generating Fat Segmentations

# %%
water_directory = "D:/GEA21/fat/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/fat_segmentations1/GEA_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_PDFF/fat/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/fat_segmentations1/SBIR_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/SBIR_T1/fat/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/fat_segmentations1/T1_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

water_directory = "D:/WLS02_UCSD/fat/"
water_folders = sorted(os.listdir(water_directory))

for i in range(len(water_folders)):
    img_directory = glob.glob(os.path.join(water_directory + water_folders[i], "*"))[0] + "/"
    totalsegmentator(img_directory, f"D:/GEA21/fat_segmentations1/WLS_{water_folders[i]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

# %% [markdown]
# ## Generating Prediction Segmentations

# %%
prediction_directory = "C:/Users/User/Desktop/inout_pdff/outputs/predictions/"
predictions = os.listdir(prediction_directory)

for prediction in predictions:
    prediction_dir = prediction_directory + prediction
    totalsegmentator(prediction_dir, f"D:/GEA21/pred_segmentations/{prediction.split('.')[0]}_seg", task='liver_segments_mr', output_type='nifti', ml=True)

# %% [markdown]
# ## Checking Segmentations

# %%
segmentation_directory = "D:/GEA21/fat_segmentations/"
segmentation_files = os.listdir(segmentation_directory)

for i in range(len(segmentation_files)):
    data = nib.load(segmentation_directory + segmentation_files[i]).get_fdata()
    print(data.shape)

# %%
import nibabel as nib
from nibabel.orientations import aff2axcodes

nii = nib.load("D:\GEA21\outphase_segmentations\GEA_A21_01_seg.nii")
print("Affine:\n", nii.affine)
print("Orientation codes:", aff2axcodes(nii.affine))
print("Array shape:", nii.shape)

# %%
data = nib.load("D:\GEA21/fat_segmentations\GEA_A21_01_seg.nii")

seg_data = data.get_fdata()
seg_data = (seg_data > 0).astype(np.uint8)
seg_fixed = np.flip(seg_data, axis=1)     # Flip Y
seg_fixed = np.transpose(seg_fixed, (2, 1, 0))

seg_fixed.shape

# %%
import matplotlib
print(matplotlib.get_backend())

# %%
water_directory = "D:\GEA21/fat\A21_01\FatFrac_IDEAL_IQ_PDFF_11/"
water_dicoms = os.listdir(water_directory)

for i in range():
    water = pydicom.dcmread(water_directory + water_dicoms[-i]).pixel_array
    plt.figure(figsize=(18,6))
    plt.subplot(131)
    plt.imshow(seg_fixed[i,:,:], cmap='gray')
    plt.subplot(132)
    plt.imshow(water, cmap='gray')
    plt.subplot(133)
    plt.imshow(water, cmap='gray')
    plt.imshow(seg_fixed[i,:,:], alpha=0.2, cmap='Reds')
    plt.show()

# %%
data = nib.load("D:\GEA21\out_segmentations\GEA_A21_01_seg.nii")

seg_data = data.get_fdata()
seg_data = (seg_data > 0).astype(np.uint8)
seg_fixed = np.flip(seg_data, axis=1)     # Flip Y
seg_fixed = np.transpose(seg_fixed, (2, 1, 0))

seg_fixed.shape

# %%
water_directory = "D:\GEA21\in_out\A21_01\InPhase_LAVA_FLEX_adb_+_pelvis_1001/"
water_dicoms = os.listdir(water_directory)

for i in range(100, 130):
    water = pydicom.dcmread(water_directory + water_dicoms[-i]).pixel_array
    plt.figure(figsize=(18,6))
    plt.subplot(131)
    plt.imshow(seg_fixed[i,:,:], cmap='gray')
    plt.subplot(132)
    plt.imshow(water, cmap='gray')
    plt.subplot(133)
    plt.imshow(water, cmap='gray')
    plt.imshow(seg_fixed[i,:,:], alpha=0.2, cmap='Reds')
    plt.show()
